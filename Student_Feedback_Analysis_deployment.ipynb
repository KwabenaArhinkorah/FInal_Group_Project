# %% [markdown]
# <a href="https://colab.research.google.com/github/KwabenaArhinkorah/FInal_Group_Project/blob/main/Student_Feedback_Analysis_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install NeMo
from google.colab import drive
drive.mount('/content/drive')
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[nlp]
# Out:
# Mounted at /content/drive
# DEPRECATION: git+https://github.com/NVIDIA/NeMo.git@main#egg=nemo_toolkit[nlp] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting nemo_toolkit[nlp]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-6x01i1lv/nemo-toolkit_5d7516fec5ce4f458c0f1e4c134ce950
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-6x01i1lv/nemo-toolkit_5d7516fec5ce4f458c0f1e4c134ce950
#   Resolved https://github.com/NVIDIA/NeMo.git to commit acf1d9bdc2cd0e5490a16f2a5d33b56ca7083f98
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (0.19.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (0.58.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.23.5)
# Collecting onnx>=1.7.0 (from nemo_toolkit[nlp])
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 66.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (2.8.2)
# Collecting ruamel.yaml (from nemo_toolkit[nlp])
#   Downloading ruamel.yaml-0.18.5-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.2.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (67.7.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (2.14.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (4.66.1)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (2.1.0)
# Collecting wget (from nemo_toolkit[nlp])
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.14.1)
# Collecting boto3 (from nemo_toolkit[nlp])
#   Downloading boto3-1.33.6-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 15.3 MB/s eta 0:00:00
# Collecting einops (from nemo_toolkit[nlp])
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.6 MB/s eta 0:00:00
# Collecting faiss-cpu (from nemo_toolkit[nlp])
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 70.2 MB/s eta 0:00:00
# Collecting fasttext (from nemo_toolkit[nlp])
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flask-restful (from nemo_toolkit[nlp])
#   Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl (26 kB)
# Collecting ftfy (from nemo_toolkit[nlp])
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (4.6.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (3.9.0)
# Collecting ijson (from nemo_toolkit[nlp])
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (0.42.1)
# Collecting markdown2 (from nemo_toolkit[nlp])
#   Downloading markdown2-2.4.10-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (3.7.1)
# Collecting megatron-core==0.3.0 (from nemo_toolkit[nlp])
#   Downloading megatron_core-0.3.0-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.5/194.5 kB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (3.8.1)
# Collecting opencc<1.1.7 (from nemo_toolkit[nlp])
#   Downloading OpenCC-1.1.6-cp310-cp310-manylinux1_x86_64.whl (778 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.3/778.3 kB 62.4 MB/s eta 0:00:00
# Collecting pangu (from nemo_toolkit[nlp])
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Collecting rapidfuzz (from nemo_toolkit[nlp])
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 123.9 MB/s eta 0:00:00
# Collecting rouge-score (from nemo_toolkit[nlp])
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu (from nemo_toolkit[nlp])
#   Downloading sacrebleu-2.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 12.6 MB/s eta 0:00:00
# Collecting sentence-transformers (from nemo_toolkit[nlp])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorstore<0.1.46 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (0.1.45)
# Collecting zarr (from nemo_toolkit[nlp])
#   Downloading zarr-2.16.1-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.9/206.9 kB 25.9 MB/s eta 0:00:00
# Collecting hydra-core<=1.3.2,>1.3 (from nemo_toolkit[nlp])
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 18.5 MB/s eta 0:00:00
# Collecting omegaconf<=2.3 (from nemo_toolkit[nlp])
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
# Collecting pytorch-lightning<=2.0.7,>=2.0 (from nemo_toolkit[nlp])
#   Downloading pytorch_lightning-2.0.7-py3-none-any.whl (724 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 53.5 MB/s eta 0:00:00
# Collecting torchmetrics>=0.11.0 (from nemo_toolkit[nlp])
#   Downloading torchmetrics-1.2.1-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 61.8 MB/s eta 0:00:00
# Collecting transformers<=4.33.3,>=4.0.1 (from nemo_toolkit[nlp])
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 87.8 MB/s eta 0:00:00
# Collecting wandb (from nemo_toolkit[nlp])
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 87.2 MB/s eta 0:00:00
# Collecting webdataset<=0.1.62,>=0.1.48 (from nemo_toolkit[nlp])
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Collecting datasets (from nemo_toolkit[nlp])
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (7.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.5.3)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[nlp]) (1.10.13)
# Collecting sacremoses>=0.0.43 (from nemo_toolkit[nlp])
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 63.7 MB/s eta 0:00:00
# Collecting sentencepiece<1.0.0 (from nemo_toolkit[nlp])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.6 MB/s eta 0:00:00
# Collecting youtokentome>=1.0.5 (from nemo_toolkit[nlp])
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core<=1.3.2,>1.3->nemo_toolkit[nlp])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core<=1.3.2,>1.3->nemo_toolkit[nlp]) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[nlp]) (3.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.5->nemo_toolkit[nlp]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.5->nemo_toolkit[nlp]) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.5->nemo_toolkit[nlp]) (2023.6.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf<=2.3->nemo_toolkit[nlp]) (6.0.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.7.0->nemo_toolkit[nlp]) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->nemo_toolkit[nlp]) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->nemo_toolkit[nlp]) (1.16.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[nlp]) (2023.6.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[nlp])
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[nlp]) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[nlp]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[nlp]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[nlp]) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.9 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (0.4.1)
# Collecting braceexpand (from webdataset<=0.1.62,>=0.1.48->nemo_toolkit[nlp])
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting botocore<1.34.0,>=1.33.6 (from boto3->nemo_toolkit[nlp])
#   Downloading botocore-1.33.6-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 84.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->nemo_toolkit[nlp])
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3->nemo_toolkit[nlp])
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[nlp]) (9.0.0)
# Collecting pyarrow-hotfix (from datasets->nemo_toolkit[nlp])
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->nemo_toolkit[nlp])
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[nlp]) (3.4.1)
# Collecting multiprocess (from datasets->nemo_toolkit[nlp])
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[nlp]) (3.9.1)
# Collecting pybind11>=2.2 (from fasttext->nemo_toolkit[nlp])
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Collecting aniso8601>=0.82 (from flask-restful->nemo_toolkit[nlp])
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.10/dist-packages (from flask-restful->nemo_toolkit[nlp]) (2.2.5)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from flask-restful->nemo_toolkit[nlp]) (2023.3.post1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->nemo_toolkit[nlp]) (0.2.12)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->nemo_toolkit[nlp]) (4.11.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->nemo_toolkit[nlp]) (0.41.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score->nemo_toolkit[nlp]) (1.4.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->nemo_toolkit[nlp])
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 54.9 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu->nemo_toolkit[nlp])
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->nemo_toolkit[nlp]) (0.9.0)
# Collecting colorama (from sacrebleu->nemo_toolkit[nlp])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->nemo_toolkit[nlp]) (4.9.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nemo_toolkit[nlp]) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nemo_toolkit[nlp]) (3.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->nemo_toolkit[nlp]) (0.16.0+cu118)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[nlp]) (3.0.1)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->nemo_toolkit[nlp])
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[nlp]) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->nemo_toolkit[nlp])
#   Downloading sentry_sdk-1.38.0-py2.py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 29.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->nemo_toolkit[nlp])
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb->nemo_toolkit[nlp])
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[nlp]) (1.4.4)
# Collecting asciitree (from zarr->nemo_toolkit[nlp])
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fasteners (from zarr->nemo_toolkit[nlp])
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting numcodecs>=0.10.0 (from zarr->nemo_toolkit[nlp])
#   Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 103.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.6->boto3->nemo_toolkit[nlp]) (2.0.7)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.8->flask-restful->nemo_toolkit[nlp]) (2.1.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[nlp]) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[nlp])
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[nlp]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[nlp]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[nlp]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[nlp]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->nemo_toolkit[nlp]) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->nemo_toolkit[nlp]) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.33.3,>=4.0.1->nemo_toolkit[nlp]) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->nemo_toolkit[nlp]) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[nlp])
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[nlp]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[nlp]) (3.2.2)
# Building wheels for collected packages: antlr4-python3-runtime, youtokentome, fasttext, nemo_toolkit, rouge-score, sentence-transformers, wget, asciitree
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=458ff01ef90ae0c210480b3ede03a6685ad90a424219c04ec8d25ca574312016
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=1951517 sha256=ce50440fcdc5571ba3c7c1b70d5991ab4d6629453ebc9305af445a6250aeab3d
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199772 sha256=9be42c4904acc0da436fa0d4e24ffe327a37ce0185158891f42f8c44ebfc0506
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for nemo_toolkit (pyproject.toml) ... done
#   Created wheel for nemo_toolkit: filename=nemo_toolkit-1.21.0rc0-py3-none-any.whl size=2682865 sha256=c61474dbcb5f7144ab973f2cb8d26427d2b649be8e446bb692f09d7fe044a57b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-69osekc7/wheels/6c/d2/4f/1572b895b6a4dbd9fdf534c882d9bc6e94e700a6db5bb20423
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=ff5d424596e379c99cd6f1b3b0bdb5ddfb2b261e9d805a4a4dcfae782ef8452d
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=8de40e252c33894aa6687e1138c041811d63fc1f9f8d8fa8431925a33bfe33a6
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=57ec48aa0f44b3dd576c3505e1ba831e5e4b3914775e09bf7c4ec26b1ca677e3
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5033 sha256=65652a0353b765872c8343ece55ffaac77aa704c01074680724f1965d14a5c2c
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built antlr4-python3-runtime youtokentome fasttext nemo_toolkit rouge-score sentence-transformers wget asciitree
# Installing collected packages: wget, tokenizers, sentencepiece, pangu, opencc, megatron-core, ijson, faiss-cpu, braceexpand, asciitree, antlr4-python3-runtime, aniso8601, youtokentome, webdataset, smmap, setproctitle, sentry-sdk, sacremoses, ruamel.yaml.clib, rapidfuzz, pybind11, pyarrow-hotfix, portalocker, onnx, omegaconf, numcodecs, markdown2, lightning-utilities, jmespath, ftfy, fasteners, einops, docker-pycreds, dill, colorama, zarr, sacrebleu, ruamel.yaml, rouge-score, multiprocess, hydra-core, gitdb, fasttext, botocore, transformers, torchmetrics, s3transfer, GitPython, flask-restful, wandb, sentence-transformers, pytorch-lightning, datasets, boto3, nemo_toolkit
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed GitPython-3.1.40 aniso8601-9.0.1 antlr4-python3-runtime-4.9.3 asciitree-0.3.3 boto3-1.33.6 botocore-1.33.6 braceexpand-0.1.7 colorama-0.4.6 datasets-2.15.0 dill-0.3.7 docker-pycreds-0.4.0 einops-0.7.0 faiss-cpu-1.7.4 fasteners-0.19 fasttext-0.9.2 flask-restful-0.3.10 ftfy-6.1.3 gitdb-4.0.11 hydra-core-1.3.2 ijson-3.2.3 jmespath-1.0.1 lightning-utilities-0.10.0 markdown2-2.4.10 megatron-core-0.3.0 multiprocess-0.70.15 nemo_toolkit-1.21.0rc0 numcodecs-0.12.1 omegaconf-2.3.0 onnx-1.15.0 opencc-1.1.6 pangu-4.0.6.1 portalocker-2.8.2 pyarrow-hotfix-0.6 pybind11-2.11.1 pytorch-lightning-2.0.7 rapidfuzz-3.5.2 rouge-score-0.1.2 ruamel.yaml-0.18.5 ruamel.yaml.clib-0.2.8 s3transfer-0.8.2 sacrebleu-2.3.3 sacremoses-0.1.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 sentry-sdk-1.38.0 setproctitle-1.3.3 smmap-5.0.1 tokenizers-0.13.3 torchmetrics-1.2.1 transformers-4.33.3 wandb-0.16.0 webdataset-0.1.62 wget-3.2 youtokentome-1.0.6 zarr-2.16.1

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 92.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.8 MB/s eta 0:00:00

# %%
from nemo.collections import nlp as nemo_nlp
from nemo.utils.exp_manager import exp_manager

import os
import streamlit as st
import wget
import torch
import pytorch_lightning as pl
from omegaconf import OmegaConf

# %%
# %%writefile app.py

import streamlit as st

from nemo.collections import nlp as nemo_nlp
from nemo.utils.exp_manager import exp_manager
import os
import wget
import torch
import pytorch_lightning as pl

# Define a function for sentiment prediction (placeholder)
def predict_sentiment(text):

    model_path = '/content/drive/My Drive/ColabAssign/trained-model.nemo' #change to reflect your model

    model = nemo_nlp.models.TextClassificationModel.restore_from(restore_path=model_path)

    pred_dict = {0: 'Neutral', 1: 'Positive', 2: 'Negative'}

    if torch.cuda.is_available():
        model.to("cuda")
    else:
        model.to("cpu")

    # max_seq_length=512 is the maximum length BERT supports.
    results = model.classifytext(queries=text, batch_size=3, max_seq_length=512)

    # Replace this with the actual model prediction logic
    return pred_dict[results[0]] # Example

# Title and Introduction
st.title("Student Feedback Review System")
st.markdown("""
This system revolutionizes how educational institutions collect and analyze student feedback.
It leverages mobile technology, advanced analytics, and machine learning to provide insightful and data-driven feedback analysis.
Your input is valuable in enhancing the quality of education.
""")

# Feedback Input
feedback = st.text_area("Enter your feedback here:")

# Submit Button
if st.button('Submit Feedback'):
    # Process the feedback
    # (You'll need to integrate your model here to predict sentiment)
    sentiment = predict_sentiment(feedback)  # Replace with your model function
    st.write("Predicted Sentiment Feedback:", sentiment)
# Out:
# Writing app.py

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 1.607s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.71.44.237
# npx: installed 22 in 1.476s
# your url is: https://ninety-bees-yell.loca.lt
